# %%
2+2
# Out:
# 4

# %%
3*7
# Out:
# 21

# %%
(2+4)*3
# Out:
# 18

# %%
spam = 42

# %%
spam
# Out:
# 42

# %%
42
# Out:
# 42

# %%
spam = "Hello"

# %%
spam
# Out:
# 'Hello'

# %%
spam + "World"
# Out:
# 'HelloWorld'

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
myAge = input()
# Out:
# 26

# %%
myAge
# Out:
# '26'

# %%
name = 'Alice'
if name == 'Alice':
    print ('Hi Alice')
print('DOne')
# Out:
# Hi Alice
# DOne

# %%
password ='swordfish'
if password == 'swordfish':
    print('Access granted.')
else:
    print('Wrong password.')
# Out:
# Access granted.

# %%
name = 'Bob'
age = 3000
if name == 'Alice':
    print('Hi Alice')
elif age < 12:
    print('You are not Alice, kiddo.')
elif age > 2000:
    print('Unlike you, Alice is not an undead, immortal Vampire.')
elif age > 100:
    print('You are not Alice, grannie.')
# Out:
# Unlike you, Alice is not an undead, immortal Vampire.

# %%
print('Enter a name.')
name = input()
if name:
    print('THank you for entering a name.')
else:
    print('You did not enter a name.')
# Out:
# Enter a name.
# Charlo
# THank you for entering a name.

# %%
spam = 0 
while spam <5:
    print('Hello World!')
    spam = spam + 1
# Out:
# Hello World!
# Hello World!
# Hello World!
# Hello World!
# Hello World!

# %%
name = ''
while name != 'your name':
    print('Please type your name.')
    name = input()
print('Thank you!')
# Out:
# Please type your name.
# Charlotte
# Please type your name.

# %%
while True: 
    print('Hello!')
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!
# ...

# %%
spam = 0
while spam < 5:
    spam = spam + 1
    if spam == 3:
        continue
    print('spam is ' + str(spam))
# Out:
# spam is 1
# spam is 2
# spam is 4
# spam is 5

# %%
print('My name is')
for i in range(5):
    print('Jimmy Five TImes ' + str(i))
# Out:
# My name is
# Jimmy Five TImes 0
# Jimmy Five TImes 1
# Jimmy Five TImes 2
# Jimmy Five TImes 3
# Jimmy Five TImes 4

# %%
total = 0
for num in range(101):
    total = total + num
print(total)
# Out:
# 5050

# %%
import random
random.randint(1,10)
# Out:
# 8

# %%
import random, sys, os, math
from random import *
randint(1,10)
# Out:
# 2

# %%
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\charl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import sys
print('Hello')
sys.exit()
print('goodbye')
# Out:
# Hello
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\charl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3351: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
import pyperclip
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-9e1950f73201> in <module>
# ----> 1 import pyperclip
#
# ModuleNotFoundError: No module named 'pyperclip'

# %%
import pyperclip

# %%
def hello():
    print('Hody!')
    print('Howdy!!')
    print('Hello there.')
    
hello()
# Out:
# Hody!
# Howdy!!
# Hello there.

# %%
def hello(name):
    print('Howdy ' + name)
    print('Howdy!!')
    print('Hello there.')
    
hello('Alice')
# Out:
# Howdy Alice
# Howdy!!
# Hello there.

# %%
def plusOne(number):
    return number + 1

newNumber = plusOne(5)
print(newNumber)
# Out:
# 6

# %%
print('Hello', end='')
print('World')
# Out:
# HelloWorld

# %%
print('cat', 'dog', sep='ABC')
# Out:
# catABCdog

# %%
spam = 43 # global variable
def eggs():
    spam = 42 # local variable
    
print('Some code here.')
print('Some more code.')
# Out:
# Some code here.
# Some more code.

# %%
def spam():
    global eggs # changes global variable locally
    egg = 99
    bacon()
    print(eggs)

eggs = 42
spam()
print(eggs)
# Out:
# 42
# 42

# %%
# local variables cant be used in global scope

# %%
# local variables belonging to different functions, having same name, DONT have same disk space

# %%
# global variables can be read from local scope

# %%
def div42by(divideBy):
    try: 
        return 42/divideBy
    except ZeroDivisionError:
        print('Error: You tried to divide by zero.')

print(div42by(2))
print(div42by(12))
print(div42by(0))
print(div42by(1))
# Out:
# 21.0
# 3.5
# Error: You tried to divide by zero.
# None
# 42.0

# %%
print('How many cats do you have?')
numCats = input()
try:
    if int(numCats) >= 4:
        print('That is a lot of cats.')
    else:
        print('Thats not that many cats')
except ValueError:
    print('You did not enter a number.')
# Out:
# How many cats do you have?
# aesdgnh
# You did not enter a number.

# %%
# This is a guess the number game.
import random
print('Hello. What is your name?')
name = input()
secretNumber = random.randint(1,20)
print('Well, ' + name + ', I am thinking of a number between 1 and 20.')

# Ask the player to guess 6 times.
for guessesTaken in range(1, 7):
    print('Take a guess.')
    guess = int(input()) #we have to make guess also an integer
    
    if guess < secretNumber:
        print('Your guess is too low.')
    elif guess > secretNumber:
        print('Your guess is too high')
    else:
        break # This condition is for the correct guess!

if guess == secretNumber:
    print('Good job, ' + name + '! You guessed my number in ' + str(guessesTaken) + ' guesses taken')
else:
    print('Nope. The number I was thinking of was ' + str(secretNumber))
# Out:
# Hello. What is your name?
# awd
# Well, awd, I am thinking of a number between 1 and 20.
# Take a guess.
# 20
# Your guess is too high
# Take a guess.
# 1
# Your guess is too low.
# Take a guess.
# 2
# Your guess is too low.
# Take a guess.
# 3
# Your guess is too low.
# Take a guess.
# 4
# Your guess is too low.
# Take a guess.
# 5
# Your guess is too low.
# Nope. The number I was thinking of was 19

# %%
['cat', 'bat', 'rat', 'elephant']
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
spam
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %%
spam[0]
# Out:
# 'cat'

# %%
spam[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-a5e168d12ce4> in <module>
# ----> 1 spam[9]
#
# IndexError: list index out of range

# %%
spam[6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-ff63a299521f> in <module>
# ----> 1 spam[6]
#
# IndexError: list index out of range

# %%
spam = [['cat','bat'], [10,20,30,40,50]]

# %%
spam[1][4]
# Out:
# 50

# %%
spam = [-2]

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
spam[-2]
# Out:
# 'rat'

# %%
'The ' + spam[-1] + ' is afraid of the ' + spam[-3] + '.'
# Out:
# 'The elephant is afraid of the bat.'

# %%
spam[1:3] #index starts at one and goes up to three, not including indices inbetween
# Out:
# ['bat', 'rat']

# %%
spam = 'Hello'

# %%
spam
# Out:
# 'Hello'

# %%
spam = [10, 20, 30]

# %%
spam[1] = 'Hello' #assign new value to index

# %%
spam
# Out:
# [10, 'Hello', 30]

# %%
spam[1:3] = ['Cat', 'Dog', 'Mouse']

# %%
spam
# Out:
# [10, 'Cat', 'Dog', 'Mouse']

# %%
spam = ['cat', 'rat', 'bat', 'elephant']

# %%
spam[:2]
# Out:
# ['cat', 'rat']

# %%
del spam[2]

# %%
spam
# Out:
# ['cat', 'rat', 'elephant']

# %%
len('hello')
# Out:
# 5

# %%
len([1,2,3])
# Out:
# 3

# %%
'Hello ' + 'world'
[1,2,3] + [4,5,6]
'Hello' * 3
[1,2,3] * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
# a lot of things you can do with strings is what you can do with lists

# %%
list('hello')
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %%
'howdy' in ['hello', 'hi', 'howdy']
# Out:
# True

# %%
'howdy' not in ['hello', 'hi', 'howdy']
# Out:
# False
